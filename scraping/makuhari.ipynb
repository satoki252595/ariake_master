# %%
import requests
from bs4 import BeautifulSoup

def increment_month(ym):
    """
    YYYYMM形式の整数を受け取り、1ヶ月進めた値を返す。
    例：202012 -> 202101, 202101 -> 202102
    """
    year = ym // 100
    month = ym % 100
    month += 1
    if month > 12:
        month = 1
        year += 1
    return year * 100 + month

def scrape_event_detail(detail_url):
    response = requests.get(detail_url)
    response.encoding = response.apparent_encoding
    soup = BeautifulSoup(response.text, 'html.parser')
    
    event_data = {}
    
    # タイトル
    title_tag = soup.select_one('.eventDetail .eventTit')
    event_data['detail_title'] = title_tag.get_text(strip=True) if title_tag else None
    
    # カテゴリ
    category_tag = soup.select_one('.eventDetail .category')
    event_data['detail_category'] = category_tag.get_text(strip=True) if category_tag else None
    
    # 説明文
    disc_tag = soup.select_one('.eventDetail .disc')
    event_data['description'] = disc_tag.get_text(strip=True) if disc_tag else None
    
    # 開催期間
    date_dd = soup.select_one('.eventDetail dl.date dd')
    if date_dd:
        date_main = date_dd.select_one('.main')
        event_data['date_period'] = date_main.get_text(strip=True) if date_main else None

    # 開催時間
    time_dd = soup.select_one('.eventDetail dl.time dd')
    if time_dd:
        time_main = time_dd.select_one('.main')
        time_note = time_dd.select_one('.note')
        event_data['time_main'] = time_main.get_text(strip=True) if time_main else None
        event_data['time_note'] = time_note.get_text(strip=True) if time_note else None

    # 対象者/入場料
    person_dd = soup.select_one('.eventDetail dl.person dd .authorP')
    if person_dd:
        target_div = person_dd.select_one('.target')
        price_div = person_dd.select_one('.price')
        event_data['detail_target'] = target_div.get_text(strip=True) if target_div else None
        event_data['detail_price'] = price_div.get_text(strip=True) if price_div else None

    # 利用施設
    facility_dd = soup.select('.eventDetail dl.facility dd .hall')
    if facility_dd:
        facilities = []
        for hall in facility_dd:
            hall_name = hall.select_one('.hallName')
            hall_no = hall.select_one('.hallNo')
            facility_str = ''
            if hall_name:
                facility_str += hall_name.get_text(strip=True)
            if hall_no:
                facility_str += ' ' + hall_no.get_text(strip=True)
            facilities.append(facility_str.strip())
        event_data['facilities'] = facilities

    # 主催者
    organizer_dd = soup.select_one('.eventDetail dl.organizer dd')
    event_data['organizer'] = organizer_dd.get_text(strip=True) if organizer_dd else None

    # URL
    url_dd = soup.select_one('.eventDetail dl.contact dd .url a')
    event_data['official_url'] = url_dd.get('href') if url_dd else None

    # 詳細ページ画像
    thumb_img = soup.select_one('.eventDetail .thumb img')
    if thumb_img:
        img_src = thumb_img.get('src')
        if img_src and img_src.startswith('/'):
            img_src = 'https://www.m-messe.co.jp' + img_src
        event_data['detail_image_url'] = img_src
    else:
        event_data['detail_image_url'] = None
    
    return event_data


def scrape_events_for_month(month, pmonth, ss, max_pages=100):
    """
    指定のmonth, pmonth, ssでイベント一覧と詳細情報を取得。
    max_pagesは1ヶ月あたりに取得を試みるページ数の上限。
    イベントが取得できなくなったらbreak。
    """
    all_events = []
    for page in range(1, max_pages+1):
        url = "https://www.m-messe.co.jp/event/"
        params = {
            "month": str(month),
            "c": "",
            "word": "",
            "page": str(page),
            "pmonth": str(pmonth),
            "ss": str(ss),
        }
        response = requests.get(url, params=params)
        response.encoding = response.apparent_encoding
        soup = BeautifulSoup(response.text, "html.parser")

        event_list = soup.select("ul.eventList > li.eventInr.clear")
        if not event_list:
            # イベントがなければbreak
            break

        for li in event_list:
            a_tag = li.find("a")
            if a_tag:
                detail_url = a_tag.get("href")
                if detail_url and detail_url.startswith("/event/detail/"):
                    detail_url = "https://www.m-messe.co.jp" + detail_url
                else:
                    detail_url = None
            else:
                detail_url = None

            category_div = li.select_one(".category")
            category = category_div.get_text(strip=True) if category_div else None

            date_div = li.select_one(".date")
            date_text = date_div.get_text(strip=True) if date_div else None

            title_div = li.select_one(".eventTit")
            title = title_div.get_text(strip=True) if title_div else None

            target_div = li.select_one(".target")
            target_text = target_div.get_text(strip=True).replace("対象", "") if target_div else None

            thumb_div = li.select_one(".thumb img")
            image_url = thumb_div.get("src") if thumb_div else None
            if image_url and image_url.startswith("/"):
                image_url = "https://www.m-messe.co.jp" + image_url

            event = {
                "title": title,
                "date": date_text,
                "category": category,
                "target": target_text,
                "detail_url": detail_url,
                "image_url": image_url,
                "month_param": month
            }
            
            # detail_urlがあれば詳細情報取得
            if detail_url:
                detail_data = scrape_event_detail(detail_url)
                event.update(detail_data)
            
            all_events.append(event)

    return all_events

def scrape_all_events(start_month=202012, end_month=202606):
    """
    start_monthからend_monthまで月を進めながらイベントを取得。
    ssはstart_monthから進めるたびに+1していく。
    pmonthは固定値としてend_monthを渡します。
    """
    all_events = []
    ss = 0
    pmonth = end_month

    current_month = start_month
    while current_month <= end_month:
        events = scrape_events_for_month(current_month, pmonth, ss)
        all_events.extend(events)

        # 次の月へ
        current_month = increment_month(current_month)
        ss += 1

    return all_events


# 例: 2020年12月から2021年6月までのイベントを取得
data = scrape_all_events(start_month=202012, end_month=202606)

# %%
data[-1]
# Out:
# {'title': '通信制高校・サポート校合同相談会',
#  'date': '2025.11.24(月)',
#  'category': 'イベント',
#  'target': '一般',
#  'detail_url': 'https://www.m-messe.co.jp/event/detail/7921',
#  'image_url': 'https://www.m-messe.co.jp/saved/images/event/8e/63/c5f31288126de5d09a023f5150e8ebe514bf8e63.jpg',
#  'month_param': 202511,
#  'detail_title': '通信制高校・サポート校合同相談会',
#  'detail_category': 'イベント',
#  'description': '通信制高校、サポート校、高等専修学校、技能連携校等の多様な進路についての合同相談会です。各校ブースで話を聴けるほか、通信制のしくみに関する講演や在校生・卒業生の体験談、各種相談コーナーもあります。',
#  'date_period': '2025年11月24日(月・祝)',
#  'time_main': '10:30～15:30',
#  'time_note': None,
#  'facilities': ['国際会議場'],
#  'organizer': '学びリンク株式会社',
#  'official_url': 'https://www.stepup-school.net/soudankai/',
#  'detail_image_url': 'https://www.m-messe.co.jp/cache/images/event/8e/63/c5f31288126de5d09a023f5150e8ebe514bf8e63.1200x1200.none.jpg'}

# %%
import pandas as pd

# 辞書型データをDataFrameに変換
df = pd.DataFrame(data)

# 1018                       第14回 映像・CG制作展(第16回 コンテンツ東京内)         展示会・見本市
# 1019          第12回 広告クリエイティブ・マーケティングEXPO(第16回 コンテンツ東京内)         展示会・見本市
# 1020              第12回 コミュニケーションデザインEXPO(第16回 コンテンツ東京内)         展示会・見本市
# 1021                 第12回 先端デジタル テクノロジー展(第16回 コンテンツ東京内)         展示会・見本市
# 1022                                 第4回 XR・メタバース総合展【秋】         展示会・見本市
# 1023                 第9回 ドリンク ジャパン - [飲料][液状食品]開発・製造展 -         展示会・見本市
# 1024                                第5回 フードテックWeek [東京]         展示会・見本市
# 1025                                第5回 フードテックジャパン [東京]         展示会・見本市
# 1026                             第1回 食品衛生イノベーション 展 [東京]         展示会・見本市
# 1027                           第3回 飲食業界イノベーションWeek [東京]         展示会・見本市
# 1028                             第3回スマートレストラン EXPO [東京]         展示会・見本市
# 1029                          第1回 レストランマネジメント EXPO [東京]         展示会・見本市
# 1030                  ≠ME 全国ツアー追加公演2024 「修学旅行、同じ班がいいな。」          音楽イベント
# 1031                          ≒JOY ホールツアー2024「今日から君は恋人」          音楽イベント
# 1032                          第9回 "日本の食品" 輸出EXPO WINTER         展示会・見本市
# 1033                 第5回 JFEX WINTER ([国際]食品・飲料 商談Week)         展示会・見本市
# 1034                第5回 加工食品 EXPO  - JFEX FOOD WINTER -         展示会・見本市
# 1035       第5回 ワイン・酒 EXPO  - JFEX WINE&SPIRITS WINTER -         展示会・見本市
# 1036          第3回 プレミアム食品 EXPO  - JFEX PREMIUM WINTER -         展示会・見本市
# 1037               第1回 生鮮食品 EXPO  - JFEX FRESH WINTER -         展示会・見本市
# 1038           第1回 次のフードトレンド EXPO  - JFEX NEXT WINTER -         展示会・見本市
# 1039        第1回 インバウンド向け食品 EXPO  - JFEX インバウンド WINTER -         展示会・見本市
# 1040                            第38回日本泌尿器内視鏡・ロボティクス学会総会           学会・会議
# 1041                             声優グランプリ30周年記念「声グラFES.」            イベント
#
#                                             description  \
# 995   KAMITSUBAKI STUDIOによるリアル会場でのライブシリーズ「KAMITSUBAK...
# 996   そらる、自身の誕生日を含む幕張メッセ2daysのワンマンライブ『SORARU Birthda...
# 997   かねたや家具店が主催する家具のセール販売会です。イベント総開催数は300回を超えており、国内...
# 998                        学会テーマ「未来の医療をデザインする薬学・薬剤師の視点」
# 999                                  ウィンタースポーツ用品の販売イベント
# 1000  KAMITSUBAKI STUDIOによるリアル会場でのライブシリーズ「KAMITSUBAK...
# 1001  全国の市町村長等が一堂に会して議論・交流を行うことを通じて、地域活性化の一層の進展・普及を図...
# 1002                  最先端技術を目の前で実演!話題の新技術や新製品を体感してください!
# 1003  サイボウズのクラウドサービス「キントーン」の事例セッションや120以上の展示ブースが集まる総...
# 1004                                                医学会
# 1005  WATWING初の幕張メッセイベントホールというメモリアルな2日間を彩るべく、場外外でも、F...
# 1006  氣志團万博2024～シン・キシダンバンパク～ supported by ALL FREE11...
# 1007  Inter BEEは歴史と実績に裏づけされた、日本随一の音と映像と通信のプロフェッショナル展...
# 1008  ミュージカル『刀剣乱舞』シリーズの九周年を記念した公演、ミュージカル『刀剣乱舞』 祝玖寿 乱...
# 1009      本大会のメインテーマは、『細胞診の現況と展望 ～細胞を見る、診る、究める～』としています。
# 1010  AI・ブロックチェーン・量子コンピュータの最新テクノロジーに関する3つの展示会と、DXを推進...
# 1011  生成AI・ディープラーニング、機械学習、エッジAI、自然言語処理、画像・音声認識、対話AIな...
# 1012  最新の研究からアプリケーションまで、ブロックチェーン技術のすべてが一堂に出展。製造業・金融・...
# 1013  最新の研究からアプリケーションまで、量子コンピュータ技術のすべてが一堂に出展。製造業、金融機...
# 1014  デジタル人材の育成を支援する企業が一堂に出展。DX推進に不可欠なデジタル人材を育成したい企業...
# 1015  コンテンツ制作、映像・CG制作・広告デザイン・ブランディング、権利・IT・最先端デジタルテク...
# 1016  世界中からあらゆるキャラクターやブランドが出展する、日本最大のライセンシング商談展。メーカー...
# 1017  実際に制作をされるクリエイター本人が出展する、商談のための展示会。〝クリエイターに直接依頼を...
# 1018  映像制作会社、アニメ制作、ゲーム制作、音楽制作会社、映像制作ツール、CG制作ツールなどが出展...
# 1019  「クリエイティブ」を活用したいと考える企業が急速に増加。そのような企業クライアントと「クリエ...
# 1020  企業価値・商品価値を上げ、CXを向上させるためのコミュニケーションデザインやブランディング戦...
# 1021  最新のディスプレイ技術やインタラクティブコンテンツ、サウンドテクノロジーなど表現技術の最先端...
# 1022  「メタバース」や「デジタルツイン」など、生活や社会を革新していく技術として昨今注目が集まるX...
# 1023  本展は、飲料・酒類の研究・製造向けの国際商談展です。製造・包装機械・研究機器・原料・素材・マ...
# 1024  本展は食品製造の自動化・DXに特化した「フードテック ジャパン」と「食品衛生イノベーション展...
# 1025  本展は食品製造の自動化・DXに特化した展示会です。食品メーカーの生産・製造・品質管理部門に効...
# 1026  本展は、食品製造業における重要テーマである「食品衛生の課題解決」のための専門展です。AI・外...
# 1027  本展は、飲食店の自動化・DXに特化した「スマートレストランEXPO」と「レストランマネジメン...
# 1028  飲食店における人手不足問題・労働環境の改善といった課題を先端テクノロジー(ロボット・IoT・...
# 1029  本展は、飲食店の経営や店舗管理の課題を解決するための専門展です。受発注システム、勤怠管理シス...
# 1030                  ≠ME 全国ツアー2024「修学旅行、同じ班がいいな。」の追加公演
# 1031                                          ≒JOYコンサート
# 1032  農畜産物・水産物から、飲料・調味料・加工食品まで、世界に誇る"日本の食品"が一堂に出展、海外...
# 1033  日本各地・世界各国から食品・飲料が集結する総合展示会。加工食品、酒類、高級食品、生鮮食品、イ...
# 1034  即席食品・冷凍食品・麺類・レトルト食品、菓子、調味料、健康食品等の加工食品企業が出展する専門...
# 1035  世界中のワイン、ビール、ウイスキー、日本酒、焼酎、果実酒、リキュール等の酒類の企業が出展する...
# 1036  日本・世界の最高級・ワンランク上の食品・飲料にターゲットを絞った専門展。高級スーパー、百貨店...
# 1011                                               None           関係者
# 1012                                               None           関係者
# 1013                                               None           関係者
# 1014                                               None           関係者
# 1015                                               None           関係者
# 1016                                               None           関係者
# 1017                                               None           関係者
# 1018                                               None           関係者
# 1019                                               None           関係者
# 1020                                               None           関係者
# 1021                                               None           関係者
# 1022                                               None           関係者
# 1023                                               None           関係者
# 1024                                               None           関係者
# 1025                                               None           関係者
# 1026                                               None           関係者
# 1027                                               None           関係者
# 1028                                               None           関係者
# 1029                                               None           関係者
# 1030           ①開場 12:30 / 開演 13:30②開場 17:30 / 開演 18:30           NaN
# 1031           ①開場 12:30 / 開演 13:30②開場 17:30 / 開演 18:30           NaN
# 1032                                               None           関係者
# 1033                                               None           関係者
# 1034                                               None           関係者
# 1035                                               None           関係者
# 1036                                               None           関係者
# 1037                                               None           関係者
# 1038                                               None           関係者
# 1039                                               None           関係者
# 1040                                               None           関係者
# 1041  2024年11月30日(土)開場16:00/開演17:002024年12月1日(日) 開場1...           NaN
#
#                                            detail_price  \
# 995                                                 NaN
# 996                                                 NaN
# 997                                                 NaN
# 998                                 会員15,000円非会員23,000円
# 999                                                 NaN
# 1000                                                NaN
# 1001                                                 無料
# 1002                                      ご招待での入場となります。
# 1003                                                NaN
# 1004  一般(会員)\t15,000円一般(非会員)\t17,000円メディカルスタッフ、大学院生\...
# 1005                                                NaN
# 1006                                                NaN
# 1007                                                NaN
# 1008                                                NaN
# 1009                           13,000円11/9以降の申込は15,000円
# 1010                                            無料(要登録)
# 1011                                            無料(要登録)
# 1012                                            無料(要登録)
# 1013                                            無料(要登録)
# 1014                                            無料(要登録)
# 1015                                            無料(要登録)
# 1016                                            無料(要登録)
# 1017                                            無料(要登録)
# 1018                                            無料(要登録)
# 1019                                            無料(要登録)
# 1020                                            無料(要登録)
# 1021                                            無料(要登録)
# 1022                                            無料(要登録)
# 1023                                                 無料
# 1024                                                 無料
# 1025                                                 無料
# 1026                                                 無料
# 1027                                                 無料
# 1028                                                 無料
# 1029                                                 無料
# 1030                                                NaN
# 1031                                                NaN
# 1032                                            無料(要登録)
# 1033                                            無料(要登録)
# 1034                                            無料(要登録)
# 1035                                            無料(要登録)
# 1036                                            無料(要登録)
# 1037                                            無料(要登録)
# 1038                                            無料(要登録)
# 1039                                            無料(要登録)
# 1040                                        学会総会HPで掲載予定
# 1041                                                NaN
#
#                                              facilities  \
# 995                                         [幕張イベントホール]
# 996                                   [国際展示場 展示ホール9〜11]
# 997                                      [国際展示場 展示ホール3]
# 998   [国際展示場 展示ホール8, 国際会議場 コンベンションホール,国際会議室,中会議室201,...
# 999                                      [国際展示場 展示ホール7]
# 1000                                        [幕張イベントホール]
# 1001  [国際会議場 コンベンションホール,国際会議室,中会議室201,213,214,215,21...
# 1002                                     [国際展示場 展示ホール1]
# 1003                                   [国際展示場 展示ホール4〜6]
# 1004                   [国際会議場 コンベンションホール,国際会議室,中会議室201]
# 1005                                        [幕張イベントホール]
# 1006                                  [国際展示場 展示ホール9〜11]
# 1007  [国際展示場 展示ホール2〜8, 国際会議場 コンベンションホール,国際会議室,中会議室20...
# 1008                                  [国際展示場 展示ホール9〜11]
# 1009           [国際会議場 コンベンションホール,国際会議室,中会議室201,301-304]
# 1010                                   [国際展示場 展示ホール4〜6]
# 1011                                   [国際展示場 展示ホール4〜6]
# 1012                                   [国際展示場 展示ホール4〜6]
# 1013                                   [国際展示場 展示ホール4〜6]
# 1014                                   [国際展示場 展示ホール4〜6]
# 1015                                   [国際展示場 展示ホール7〜8]
# 1016                                   [国際展示場 展示ホール7〜8]
# 1017                                   [国際展示場 展示ホール7〜8]
# 1018                                   [国際展示場 展示ホール7〜8]
# 1019                                   [国際展示場 展示ホール7〜8]
# 1020                                   [国際展示場 展示ホール7〜8]
# 1021                                   [国際展示場 展示ホール7〜8]
# 1022                                   [国際展示場 展示ホール7〜8]
# 1023                                   [国際展示場 展示ホール1〜3]
# 1024                                   [国際展示場 展示ホール1〜3]
# 1025                                   [国際展示場 展示ホール1〜3]
# 1026                                   [国際展示場 展示ホール1〜3]
# 1027                                   [国際展示場 展示ホール1〜3]
# 1028                                   [国際展示場 展示ホール1〜3]
# 1029                                   [国際展示場 展示ホール1〜3]
# 1030                                   [国際展示場 展示ホール2〜3]
# 1031                                   [国際展示場 展示ホール2〜3]
# 1032                                  [国際展示場 展示ホール9〜10]
# 1033                                  [国際展示場 展示ホール9〜10]
# 1034                                  [国際展示場 展示ホール9〜10]
# 1035                                  [国際展示場 展示ホール9〜10]
# 1036                                  [国際展示場 展示ホール9〜10]
# 1037                                  [国際展示場 展示ホール9〜10]
# 1038                                  [国際展示場 展示ホール9〜10]
# 1039                                  [国際展示場 展示ホール9〜10]
# 1040              [国際会議場 国際会議室,中会議室201,103-105、302-304]
# 1041                                        [幕張イベントホール]
#
#                          organizer  \
# 995                   株式会社ディスクガレージ
# 996        cielkocka / PONY CANYON
# 997                    株式会社かねたや家具店
# 998                  一般社団法人日本医療薬学会
# 999                株式会社ディー.オー.ディー.
# 1000                  株式会社ディスクガレージ
# 1001                    総務省 及び 千葉県
# 1002                       株式会社ワキタ
# 1003                     サイボウズ株式会社
# 1004  株式会社サンプラネット メディカルコンベンションユニット
# 1005       株式会社ホリプロ / 株式会社ディスクガレージ
# 1006            オフィス男闘呼塾エンターテインメント
# 1007         一般社団法人日本エレクトロニクスショー協会
# 1008             ミュージカル『刀剣乱舞』製作委員会
# 1009              第63回日本臨床細胞学会秋期大会
# 1010                  RX Japan株式会社
# 1011                  RX Japan株式会社
# 1012                  RX Japan株式会社
# 1013                  RX Japan株式会社
# 1014                  RX Japan株式会社
# 1015                  RX Japan株式会社
# 1016                  RX Japan株式会社
# 1017                  RX Japan株式会社
# 1018                  RX Japan株式会社
# 1019                  RX Japan株式会社
# 1020                  RX Japan株式会社
# 1021                  RX Japan株式会社
# 1022                  RX Japan株式会社
# 1023                 Rx Japan 株式会社
# 1024                 Rx Japan 株式会社
# 1025                 Rx Japan 株式会社
