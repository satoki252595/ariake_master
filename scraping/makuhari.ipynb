# %%
import requests
from bs4 import BeautifulSoup

def increment_month(ym):
    """
    YYYYMM形式の整数を受け取り、1ヶ月進めた値を返す。
    例：202012 -> 202101, 202101 -> 202102
    """
    year = ym // 100
    month = ym % 100
    month += 1
    if month > 12:
        month = 1
        year += 1
    return year * 100 + month

def scrape_event_detail(detail_url):
    response = requests.get(detail_url)
    response.encoding = response.apparent_encoding
    soup = BeautifulSoup(response.text, 'html.parser')
    
    event_data = {}
    
    # タイトル
    title_tag = soup.select_one('.eventDetail .eventTit')
    event_data['detail_title'] = title_tag.get_text(strip=True) if title_tag else None
    
    # カテゴリ
    category_tag = soup.select_one('.eventDetail .category')
    event_data['detail_category'] = category_tag.get_text(strip=True) if category_tag else None
    
    # 説明文
    disc_tag = soup.select_one('.eventDetail .disc')
    event_data['description'] = disc_tag.get_text(strip=True) if disc_tag else None
    
    # 開催期間
    date_dd = soup.select_one('.eventDetail dl.date dd')
    if date_dd:
        date_main = date_dd.select_one('.main')
        event_data['date_period'] = date_main.get_text(strip=True) if date_main else None

    # 開催時間
    time_dd = soup.select_one('.eventDetail dl.time dd')
    if time_dd:
        time_main = time_dd.select_one('.main')
        time_note = time_dd.select_one('.note')
        event_data['time_main'] = time_main.get_text(strip=True) if time_main else None
        event_data['time_note'] = time_note.get_text(strip=True) if time_note else None

    # 対象者/入場料
    person_dd = soup.select_one('.eventDetail dl.person dd .authorP')
    if person_dd:
        target_div = person_dd.select_one('.target')
        price_div = person_dd.select_one('.price')
        event_data['detail_target'] = target_div.get_text(strip=True) if target_div else None
        event_data['detail_price'] = price_div.get_text(strip=True) if price_div else None

    # 利用施設
    facility_dd = soup.select('.eventDetail dl.facility dd .hall')
    if facility_dd:
        facilities = []
        for hall in facility_dd:
            hall_name = hall.select_one('.hallName')
            hall_no = hall.select_one('.hallNo')
            facility_str = ''
            if hall_name:
                facility_str += hall_name.get_text(strip=True)
            if hall_no:
                facility_str += ' ' + hall_no.get_text(strip=True)
            facilities.append(facility_str.strip())
        event_data['facilities'] = facilities

    # 主催者
    organizer_dd = soup.select_one('.eventDetail dl.organizer dd')
    event_data['organizer'] = organizer_dd.get_text(strip=True) if organizer_dd else None

    # URL
    url_dd = soup.select_one('.eventDetail dl.contact dd .url a')
    event_data['official_url'] = url_dd.get('href') if url_dd else None

    # 詳細ページ画像
    thumb_img = soup.select_one('.eventDetail .thumb img')
    if thumb_img:
        img_src = thumb_img.get('src')
        if img_src and img_src.startswith('/'):
            img_src = 'https://www.m-messe.co.jp' + img_src
        event_data['detail_image_url'] = img_src
    else:
        event_data['detail_image_url'] = None
    
    return event_data


def scrape_events_for_month(month, pmonth, ss, max_pages=100):
    """
    指定のmonth, pmonth, ssでイベント一覧と詳細情報を取得。
    max_pagesは1ヶ月あたりに取得を試みるページ数の上限。
    イベントが取得できなくなったらbreak。
    """
    all_events = []
    for page in range(1, max_pages+1):
        url = "https://www.m-messe.co.jp/event/"
        params = {
            "month": str(month),
            "c": "",
            "word": "",
            "page": str(page),
            "pmonth": str(pmonth),
            "ss": str(ss),
        }
        response = requests.get(url, params=params)
        response.encoding = response.apparent_encoding
        soup = BeautifulSoup(response.text, "html.parser")

        event_list = soup.select("ul.eventList > li.eventInr.clear")
        if not event_list:
            # イベントがなければbreak
            break

        for li in event_list:
            a_tag = li.find("a")
            if a_tag:
                detail_url = a_tag.get("href")
                if detail_url and detail_url.startswith("/event/detail/"):
                    detail_url = "https://www.m-messe.co.jp" + detail_url
                else:
                    detail_url = None
            else:
                detail_url = None

            category_div = li.select_one(".category")
            category = category_div.get_text(strip=True) if category_div else None

            date_div = li.select_one(".date")
            date_text = date_div.get_text(strip=True) if date_div else None

            title_div = li.select_one(".eventTit")
            title = title_div.get_text(strip=True) if title_div else None

            target_div = li.select_one(".target")
            target_text = target_div.get_text(strip=True).replace("対象", "") if target_div else None

            thumb_div = li.select_one(".thumb img")
            image_url = thumb_div.get("src") if thumb_div else None
            if image_url and image_url.startswith("/"):
                image_url = "https://www.m-messe.co.jp" + image_url

            event = {
                "title": title,
                "date": date_text,
                "category": category,
                "target": target_text,
                "detail_url": detail_url,
                "image_url": image_url,
                "month_param": month
            }
            
            # detail_urlがあれば詳細情報取得
            if detail_url:
                detail_data = scrape_event_detail(detail_url)
                event.update(detail_data)
            
            all_events.append(event)

    return all_events

def scrape_all_events(start_month=202012, end_month=202606):
    """
    start_monthからend_monthまで月を進めながらイベントを取得。
    ssはstart_monthから進めるたびに+1していく。
    pmonthは固定値としてend_monthを渡します。
    """
    all_events = []
    ss = 0
    pmonth = end_month

    current_month = start_month
    while current_month <= end_month:
        events = scrape_events_for_month(current_month, pmonth, ss)
        all_events.extend(events)

        # 次の月へ
        current_month = increment_month(current_month)
        ss += 1

    return all_events


# 例: 2020年12月から2021年6月までのイベントを取得
data = scrape_all_events(start_month=202012, end_month=202606)

# %%
data[-1]
# Out:
# {'title': '通信制高校・サポート校合同相談会',
#  'date': '2025.11.24(月)',
#  'category': 'イベント',
#  'target': '一般',
#  'detail_url': 'https://www.m-messe.co.jp/event/detail/7921',
#  'image_url': 'https://www.m-messe.co.jp/saved/images/event/8e/63/c5f31288126de5d09a023f5150e8ebe514bf8e63.jpg',
#  'month_param': 202511,
#  'detail_title': '通信制高校・サポート校合同相談会',
#  'detail_category': 'イベント',
#  'description': '通信制高校、サポート校、高等専修学校、技能連携校等の多様な進路についての合同相談会です。各校ブースで話を聴けるほか、通信制のしくみに関する講演や在校生・卒業生の体験談、各種相談コーナーもあります。',
#  'date_period': '2025年11月24日(月・祝)',
#  'time_main': '10:30～15:30',
#  'time_note': None,
#  'facilities': ['国際会議場'],
#  'organizer': '学びリンク株式会社',
#  'official_url': 'https://www.stepup-school.net/soudankai/',
#  'detail_image_url': 'https://www.m-messe.co.jp/cache/images/event/8e/63/c5f31288126de5d09a023f5150e8ebe514bf8e63.1200x1200.none.jpg'}

# %%
import pandas as pd

# 辞書型データをDataFrameに変換
df = pd.DataFrame(data)

# %%
df[df['month_param']==202410]
# Out:
#                                                  title  \
# 935                第3回 サーキュラー・エコノミー EXPO【秋】 [CE JAPAN]
# 936                                   GX経営 WEEK【秋】2024
# 937          SMART ENERGY WEEK ～スマートエネルギー WEEK～【秋】2024
# 953                                    第5回 健康経営 EXPO 秋         展示会・見本市
# 954          第43回関東甲信越ブロック理学療法士学会・第30回千葉県理学療法学術大会 合同大会            イベント
# 955                      10月6日 インターンシップ&キャリア発見フェア 幕張会場            イベント
# 956                    GARDEX (第18回 国際 ガーデン&アウトドアEXPO)         展示会・見本市
# 957                                    第14回 TOOL JAPAN         展示会・見本市
# 958                                      第14回 農業資材EXPO         展示会・見本市
# 959                                     第9回 6次産業化 EXPO         展示会・見本市
# 960                                      第6回 畜産資材 EXPO         展示会・見本市
# 961                               第2回 農業 脱炭素・SDGs EXPO         展示会・見本市
# 962                      第14回  農業WEEK(通称 J-AGRI TOKYO)         展示会・見本市
# 963               第7回  メディカル ジャパン 東京[医療・介護・薬局 Week 東京]         展示会・見本市
# 964                                    第7回 病院EXPO [東京]         展示会・見本市
# 965                                第7回 介護&看護 EXPO [東京]         展示会・見本市
# 966                                第5回 クリニック EXPO [東京]         展示会・見本市
# 967                                第5回 次世代薬局 EXPO [東京]         展示会・見本市
# 968                                 第4回 感染対策 EXPO [東京]         展示会・見本市
# 969                                第2回 健康サポートEXPO [東京]         展示会・見本市
# 970                                    第11回 スマート農業EXPO         展示会・見本市
# 971                                   地方自治情報化推進フェア2024            イベント
# 972                         令和6年度千葉県私学振興大会～私学教育を考える集い～            イベント
# 973                                   家具メッセバザールin幕張メッセ            イベント
# 974                                        CEATEC 2024         展示会・見本市
# 975  GIGA•GIGA SONIC presented by ドラゴンエッグ ～ in 幕張メッ...          音楽イベント
# 976                                        エコメッセちば2024         展示会・見本市
# 977                                SAMURAI SONIC vol.6          音楽イベント
# 978                         営業・デジタルマーケティング Week 秋 2024         展示会・見本市
# 979                                  EC・店舗 Week 秋 2024         展示会・見本市
# 980                               Japan DX Week 秋 2024         展示会・見本市
# 981                               Japan IT Week 秋 2024         展示会・見本市
# 982                      なのはな生活協同組合 50周年特別イベント なのはなメッセ            イベント
# 983    SIXFONIA One Man Live【Six-tuation】vol.Ⅰ -CHAOS-          音楽イベント
# 984                        第15回 フィルムテック ジャパン(高機能フィルム展)         展示会・見本市
# 985                       第13回 プラスチック ジャパン(高機能プラスチック展)         展示会・見本市
# 986                             第11回 メタル ジャパン(高機能 金属展)         展示会・見本市
# 987                        第9回 セラミックス ジャパン(高機能セラミックス展)         展示会・見本市
# 988                                      第8回 接着・接合EXPO         展示会・見本市
# 989                          第7回 塗料・塗装設備展(コーティング ジャパン)         展示会・見本市
# 990                                  第4回 サステナブル マテリアル展         展示会・見本市
# 991             第1回 素材工場の脱炭素化展 - Green Process Japan -         展示会・見本市
# 992                                     第15回 高機能素材Week         展示会・見本市
# 993                  第34回 ファインテック ジャパン - 電子ディスプレイ産業展 -         展示会・見本市
# 994                           第24回 Photonix(光・レーザー技術展)         展示会・見本市
#
#                                            description  \
# 935  サーキュラーデザイン、サステナブルマテリアル、PaaS支援、資源回収・リサイクル・再製品化技...
# 936  コーポレートPPAや再エネ電力、エネマネ技術、ZEB/スマートビルや次世代空調などの企業向け...
# 937  世界中からエネルギー分野500社が出展。太陽光発電・風力発電・水素エネルギー・スマートグリッ...
# 938  世界中から部品・材料、材料開発支援、評価・測定・検査、製造装置・付帯設備、バッテリーマネジメ...
# 939  世界中からエネルギーマネジメント、蓄電システム、VPP関連技術、電力設備などが出展。技術的な...
# 940  世界中から風力発電関連の部品・駆動装置、施工・輸送、解析・計測、洋上風量技術、メンテナンス会...
# 941  世界中から水素製造・貯蔵・供給技術、評価・測定・分析機器、燃料電池部品・材料、燃料電池製品・...
# 942  世界中から太陽光パネル、施工用資材、O&M技術、周辺機器(パワコン、ケーブルなど)が出展。技...
# 943  コーポレートPPAや再エネ電力、エネマネ技術、ZEB/スマートビルや次世代空調などの企業向け...
# 944  総務・人事・経理・法務・経営者が来場する「バックオフィス向け展示会」です。9の専門展で構成さ...
# 945  危機管理・災害対策の展示会です。備蓄品、蓄電・発電設備、非常用通信など、あらゆる防災製品・サ...
# 946  オフィス向けサービスに特化した展示会です。文具・事務用品、贈答品・記念品、出張・車両管理など...
# 947  人事業務支援の展示会です。人事のDX推進、労務管理、育成・採用サービス、最新のHRテクノロジ...
# 948  働き方改革の実現を促進するための展示会です。DX推進・ハイブリッドワーク支援、AI・RPAツ...
# 949  経理・財務業務支援に特化した展示会です。財務会計システム、経費精算システム、会計・財務コンサ...
# 950  福利厚生に特化した展示会です。福利厚生代行、育児・介護、財産形成、自己啓発支援など、従業員の...
# 951  法務・コンプライアンス部門を強化・効率化を促進する展示会です。電子契約サービスをはじめとする...
# 952  広報・IR業務の効率化や企業ブランディング向上の実現を支援する展示会です。広報・IR支援/ブ...
# 953  健康管理システム、健康支援アプリ、産業医サービスなど、あらゆる健康経営サービスが一堂に出展。...
# 954                                  テーマ話そう!つながろう!理学療法
# 955                                              合同説明会
# 956  園芸・アウトドア・屋外空間製品の総合展。園芸用品、造園資材、アウトドア製品、ガーデン雑貨から...
# 957  日本最大級!プロツール&DIYの総合展。作業用品、工具、作業服、安全用品、カー用品など、プロ...
# 958  農業WEEK内で開催し、最新のハウス・露地栽培資材、納期、肥料、包装・物流、鳥獣害対策など、...
# 959  農業WEEK内で開催し、食品加工機器、OEM、鮮度・衛生管理、物流・包装、EC・販売支援など...
# 960  農業WEEK内で開催し、飼料・給餌器や、畜舎、衛生製品などの資材・設備や、ITを用いた農業/...
# 961  農業WEEK内で開催し、CO2削減製品や有機肥料など、持続可能な農業を実現するための製品が集...
# 962  「農業WEEK」は農業・畜産の総合展です。農業資材、スマート農業製品、畜産資材、6次産業化製...
# 963  医療・介護・ヘルスケアに関わるあらゆる製品・サービスが出展する総合展病院EXPO/介護&看護...
# 964               病院に必要な設備・医療機器・ITシステム・サービスが一堂に出展する専門展
# 965                介護ICT・介護/福祉機器から人材サービスが出展する介護の展示会です。
# 966     開業医のための医療機器・IT・サービス、開業支援などが出展するクリニック向け専門展示会です。
# 967        調剤機器から健康機器、ITシステム、サプリメントまでが出展する薬局向け専門展示会です。
# 968          消毒剤、飛沫防止製品、衛生用品などが出展する日本最大級の感染対策 専門展示会です。
# 969  健康管理から健康食品・フィットネス製品など、健康面をあらゆる面からサポートする製品・サービス...
# 970  農業WEEK内で開催し、最新のIT・DX、ドローン、ロボット、植物工場、人材雇用、参入支援な...
# 971  日本最大規模の地方公共団体向け情報システム展示会として、125社・団体が出展。講演では有識者...
# 972      千葉県私学の困窮を広く県民に訴えるとともに、なお一層の私立学校教育振興をはかるための大会。
# 973  かねたや家具店が主催する家具のセール販売会です。イベント総開催数は300回を超えており、国内...
# 974  あらゆる産業に必要とされる国内最大級のデジタルイノベーションの総合展。25 周年特別テーマ「...
# 975  「GIGA•GIGA SONIC」は、「日本の文化である推し活文化の存続と世界への発信」とい...
# 976  持続可能な社会の実現を目指し、市民・企業・行政・大学が実行委員会を組織し、 パートナーシップ...
# 977  「SAMURAI SONIC」は、ジャンルや世代を超えたアーティストが一堂に会する音楽イベン...
# 978  営業DX、SFA・CRM、インサイドセールス、CX向上、MAツール、データ分析・AI活用など...
# 979  ECサイト構築/運用、UI/UX改善、EC管理・店舗開発・運営、人手不足対策、リテールメディ...
# 980  AI・業務自動化、社内業務DX、現場DX、データドリブン経営などに関わる製品やサービスが一堂...
# 981  情報システム、データセンター運用・管理、ソフトウェア開発、ハードウェア設計・開発などに関わる...
# 982  なのはな生活協同組合50周年記念イベントなのはな生協組合員様、一般参加者となのはな生協お取引...
# 983  シクフォニ One Man Live【Six-tuation】vol.Ⅰ -CHAOS- 開...
# 984          電機・自動車・医療・建築など様々な分野で活用される高機能フィルムに特化した専門展。
# 985     「環境対応」「軽量化」など、多様なニーズに対応する様々なプラスチック材料や加工技術の専門展。
# 986  鉄鋼・アルミ・銅・チタン・レアメタルなどあらゆる金属材料や、金属製造過程の脱炭素化や金属リサ...
# 987    「有機材料(フィルム・プラスチック)」「金属」に次ぐ、三大材料の一つ「セラミックス」の専門展。
# 988  最先端の異種材料接合技術から一般用途まで、幅広い接着・接合の技術を取り扱う専門展。自動車・エ...
# 989  工業用途・建築用途を問わず、あらゆる塗料や塗装に関する技術が集まる専門展。「日本塗料工業会」...
# 990  生分解性樹脂やセルロースなどの環境配慮型材料をはじめ、リサイクル技術やサーキュラーエコノミー...
# 991  鉄鋼、化学、窯業・セメント、紙・パルプ、非鉄金属などの素材工場の脱炭素化に特化した専門展。燃...
# 992  樹脂・金属・セラミックス・サステナブル材料、製造プロセスの脱炭素化など、素材技術の専門展。材...
# 993  スマートフォン・ウェアラブル端末・VRディスプレイなど、用途が広がり続ける電子ディスプレイ産...
# 994  「レーザー加工」「光学部品」「光計測・分析」などのテーマで構成される「光」技術の見本市。国内...
#
#                          date_period    time_main  \
# 935      2024年10月2日(水)～2024年10月4日(金)  10:00～17:00
# 936      2024年10月2日(水)～2024年10月4日(金)  10:00～17:00
# 937      2024年10月2日(水)～2024年10月4日(金)  10:00～17:00
# 938      2024年10月2日(水)～2024年10月4日(金)  10:00～17:00
# 939      2024年10月2日(水)～2024年10月4日(金)  10:00～17:00
# 940      2024年10月2日(水)～2024年10月4日(金)  10:00～17:00
# 941      2024年10月2日(水)～2024年10月4日(金)  10:00～17:00
# 942      2024年10月2日(水)～2024年10月4日(金)  10:00～17:00
# 943      2024年10月2日(水)～2024年10月4日(金)  10:00～17:00
# 944      2024年10月2日(水)～2024年10月4日(金)  10:00～18:00
# 945      2024年10月2日(水)～2024年10月4日(金)  10:00～18:00
# 946      2024年10月2日(水)～2024年10月4日(金)  10:00～18:00
# 947      2024年10月2日(水)～2024年10月4日(金)  10:00～18:00
# 948      2024年10月2日(水)～2024年10月4日(金)  10:00～18:00
# 949      2024年10月2日(水)～2024年10月4日(金)  10:00～18:00
# 950      2024年10月2日(水)～2024年10月4日(金)  10:00～18:00
# 951      2024年10月2日(水)～2024年10月4日(金)  10:00～18:00
# 952      2024年10月2日(水)～2024年10月4日(金)  10:00～18:00
# 953      2024年10月2日(水)～2024年10月4日(金)  10:00～18:00
# 954      2024年10月5日(土)～2024年10月6日(日)
# 955                    2024年10月6日(日)  13:00～17:00
# 956     2024年10月9日(水)～2024年10月11日(金)         None
# 957     2024年10月9日(水)～2024年10月11日(金)         None
# 958     2024年10月9日(水)～2024年10月11日(金)  10:00～17:00
# 959     2024年10月9日(水)～2024年10月11日(金)  10:00～17:00
# 960     2024年10月9日(水)～2024年10月11日(金)  10:00～17:00
# 961     2024年10月9日(水)～2024年10月11日(金)  10:00～17:00
# 962     2024年10月9日(水)～2024年10月11日(金)  10:00～17:00
# 963     2024年10月9日(水)～2024年10月11日(金)  10:00～17:00
# 964     2024年10月9日(水)～2024年10月11日(金)  10:00～17:00
# 965     2024年10月9日(水)～2024年10月11日(金)  10:00～17:00
# 966     2024年10月9日(水)～2024年10月11日(金)  10:00～17:00
# 967     2024年10月9日(水)～2024年10月11日(金)  10:00～17:00
# 968     2024年10月9日(水)～2024年10月11日(金)  10:00～17:00
# 969     2024年10月9日(水)～2024年10月11日(金)  10:00～17:00
#
無料(要登録)                          [国際展示場 展示ホール5〜8]
# 936            無料(要登録)                          [国際展示場 展示ホール5〜8]
# 937            無料(要登録)                          [国際展示場 展示ホール5〜8]
# 938            無料(要登録)                          [国際展示場 展示ホール5〜8]
# 939            無料(要登録)                          [国際展示場 展示ホール5〜8]
# 940            無料(要登録)                          [国際展示場 展示ホール5〜8]
# 941            無料(要登録)                          [国際展示場 展示ホール5〜8]
# 942            無料(要登録)                          [国際展示場 展示ホール5〜8]
# 943            無料(要登録)                          [国際展示場 展示ホール5〜8]
# 944  公式ウェブサイトからの事前来場登録                          [国際展示場 展示ホール1〜5]
# 945  公式ウェブサイトからの事前来場登録                          [国際展示場 展示ホール1〜5]
# 946  公式ウェブサイトからの事前来場登録                          [国際展示場 展示ホール1〜5]
# 947  公式ウェブサイトからの事前来場登録                          [国際展示場 展示ホール1〜5]
# 948  公式ウェブサイトからの事前来場登録                          [国際展示場 展示ホール1〜5]
# 949  公式ウェブサイトからの事前来場登録                          [国際展示場 展示ホール1〜5]
# 950  公式ウェブサイトからの事前来場登録                          [国際展示場 展示ホール1〜5]
# 951  公式ウェブサイトからの事前来場登録                          [国際展示場 展示ホール1〜5]
# 952  公式ウェブサイトからの事前来場登録                          [国際展示場 展示ホール1〜5]
# 953  公式ウェブサイトからの事前来場登録                          [国際展示場 展示ホール1〜5]
# 954      学会HPをご参照ください。                                   [国際会議場]
# 955                NaN                            [国際展示場 展示ホール1]
# 956            無料(要登録)                          [国際展示場 展示ホール4〜8]
# 957            無料(要登録)                          [国際展示場 展示ホール4〜8]
# 958            無料(要登録)                          [国際展示場 展示ホール4〜8]
# 959            無料(要登録)                          [国際展示場 展示ホール4〜8]
# 960            無料(要登録)                          [国際展示場 展示ホール4〜8]
# 961            無料(要登録)                          [国際展示場 展示ホール4〜8]
# 962            無料(要登録)                          [国際展示場 展示ホール4〜8]
# 963            無料(要登録)                                   [国際展示場]
# 964            無料(要登録)                                   [国際展示場]
# 965            無料(要登録)                                   [国際展示場]
# 966            無料(要登録)                                   [国際展示場]
# 967            無料(要登録)                                   [国際展示場]
# 968            無料(要登録)                                   [国際展示場]
# 969            無料(要登録)                                   [国際展示場]
# 970            無料(要登録)                          [国際展示場 展示ホール4〜8]
# 971                 無料                         [国際展示場 展示ホール9〜11]
# 972      関係者:無料その他:招待者        [国際会議場 コンベンションホール,中会議室201,303・304]
# 973                NaN                            [国際展示場 展示ホール9]
# 974                NaN                            [国際展示場, 国際会議場]
# 975                NaN                          [国際展示場 展示ホール7〜8]
# 976                NaN                                   [国際会議場]
# 977                NaN                          [国際展示場 展示ホール7〜8]
# 978            無料(要登録)                          [国際展示場 展示ホール1〜8]
# 979            無料(要登録)                          [国際展示場 展示ホール1〜8]
# 980            無料(要登録)                          [国際展示場 展示ホール1〜8]
# 981            無料(要登録)                          [国際展示場 展示ホール1〜8]
# 982                NaN                            [国際展示場 展示ホール8]
# 983                NaN                               [幕張イベントホール]
# 984    公式ウェブサイトからの事前登録  [国際展示場 展示ホール1〜8, 国際会議場 コンベンションホール,国際会議室]
# 985    公式ウェブサイトからの事前登録  [国際展示場 展示ホール1〜8, 国際会議場 コンベンションホール,国際会議室]
# 986     公式ウェブサイトでの事前登録  [国際展示場 展示ホール1〜8, 国際会議場 コンベンションホール,国際会議室]
# 987    公式ウェブサイトからの事前登録  [国際展示場 展示ホール1〜8, 国際会議場 コンベンションホール,国際会議室]
# 988    公式ウェブサイトからの事前登録  [国際展示場 展示ホール1〜8, 国際会議場 コンベンションホール,国際会議室]
# 989    公式ウェブサイトからの事前登録  [国際展示場 展示ホール1〜8, 国際会議場 コンベンションホール,国際会議室]
# 990    公式ウェブサイトからの事前登録  [国際展示場 展示ホール1〜8, 国際会議場 コンベンションホール,国際会議室]
# 991    公式ウェブサイトからの事前登録  [国際展示場 展示ホール1〜8, 国際会議場 コンベンションホール,国際会議室]
# 992    公式ウェブサイトからの事前登録  [国際展示場 展示ホール1〜8, 国際会議場 コンベンションホール,国際会議室]
# 993    公式ウェブサイトからの事前登録  [国際展示場 展示ホール1〜8, 国際会議場 コンベンションホール,国際会議室]
# 994    公式ウェブサイトからの事前登録  [国際展示場 展示ホール1〜8, 国際会議場 コンベンションホール,国際会議室]
#
#                                   organizer  \
# 935                            RX Japan株式会社
# 936                            RX Japan株式会社
# 937                            RX Japan株式会社
# 938                            RX Japan株式会社
# 939                            RX Japan株式会社
# 940                            RX Japan株式会社
# 941                           RX Japan 株式会社
# 942                           RX Japan 株式会社
# 943                            RX Japan株式会社
# 944                           RX Japan 株式会社
# 945                           RX Japan 株式会社
# 946                           RX Japan 株式会社
# 947                           RX Japan 株式会社
# 948                           RX Japan 株式会社
# 949                           RX Japan 株式会社
# 950                           RX Japan 株式会社
# 951                           RX Japan 株式会社
# 952                           RX Japan 株式会社
# 953                           RX Japan 株式会社
# 954  日本理学療法士協会 関東甲信越ブロック協議会/一般社団法人千葉県理学療法士会
# 955                                株式会社マイナビ
# 956                            RX Japan株式会社
# 957                            RX Japan株式会社
# 958                            RX Japan株式会社
# 959                            RX Japan株式会社
# 960                            RX Japan株式会社
# 961                            RX Japan株式会社
# 962                           RX Japan 株式会社
# 963                            RX Japan株式会社
# 964                            RX Japan株式会社
# 965                            RX Japan株式会社
# 966                            RX Japan株式会社
# 967                            RX Japan株式会社
# 982  https://www.m-messe.co.jp/cache/images/event/5...
# 983  https://www.m-messe.co.jp/cache/images/event/8...
# 984  https://www.m-messe.co.jp/cache/images/event/6...
# 985  https://www.m-messe.co.jp/cache/images/event/0...
# 986  https://www.m-messe.co.jp/cache/images/event/4...
# 987  https://www.m-messe.co.jp/cache/images/event/d...
# 988  https://www.m-messe.co.jp/cache/images/event/f...
# 989  https://www.m-messe.co.jp/cache/images/event/a...
# 990  https://www.m-messe.co.jp/cache/images/event/2...
# 991  https://www.m-messe.co.jp/cache/images/event/0...
# 992  https://www.m-messe.co.jp/cache/images/event/a...
# 993  https://www.m-messe.co.jp/cache/images/event/e...
# 994  https://www.m-messe.co.jp/cache/images/event/2...

# %%
# DataFrameをCSVファイルとして保存
df.to_csv("events.csv", index=False, encoding="utf-8")

# %%
#CSVデータをevent_detailsTBLへ変換する

# %%
import csv
import re
import datetime

def parse_time_range(time_str: str):
    """
    例）"10:00～18:00" から
        open_time="10:00", close_time="18:00"
    を抽出する簡易パーサ。
    """
    pattern = r'(\d{1,2}:\d{2})\D+(\d{1,2}:\d{2})'
    match = re.search(pattern, time_str)
    if match:
        start = match.group(1)
        end = match.group(2)
        return start, end
    else:
        return "", ""

def parse_price(detail_price: str):
    """
    例）"有料\\5,000/人(招待券持参者無料)" から
         max_price=5000, min_price=0
    を抽出する簡易パーサ。
    """
    # 数字(0-9)をすべて拾ってリスト化
    # カンマや円マーク(\)があっても一旦除去して抽出
    numbers = re.findall(r'\d+', detail_price.replace(',', ''))
    if numbers:
        numeric_values = list(map(int, numbers))
        max_val = max(numeric_values)
        min_val = min(numeric_values)
    else:
        max_val = 0
        min_val = 0
    
    # 「無料」という文字列があれば最小価格を0とみなす
    if "無料" in detail_price:
        min_val = 0

    return max_val, min_val

def clean_facilities_str(facilities_str: str):
    """
    例）"['国際展示場 展示ホール1〜6']" のように
         リスト形式っぽくなっている場合は
         先頭の "['" と末尾の "']" を除去するなどして
         普通の文字列にする。
    """
    cleaned = facilities_str.strip()
    # 先頭の "['" や末尾の "']" を削除する
    cleaned = re.sub(r"^\[\'+", "", cleaned)
    cleaned = re.sub(r"\'\]$", "", cleaned)
    return cleaned

def parse_jp_date(date_str: str):
    """
    "YYYY年MM月DD日" 形式の日付文字列をパースして
    datetime.date を返す。
    例）"2020年12月2日(水)" -> date(2020,12,2)
    """
    pattern = r'(\d{4})年(\d{1,2})月(\d{1,2})日'
    match = re.search(pattern, date_str)
    if match:
        year = int(match.group(1))
        month = int(match.group(2))
        day = int(match.group(3))
        return datetime.date(year, month, day)
    return None

def expand_date_range(date_period_str: str):
    """
    "2020年12月2日(水)～2020年12月4日(金)" のような文字列を解析し、
    開始日から終了日までを "YYYY-MM-DD" のリストにして返す。
    ※ 開始日や終了日がパースできなかった場合は空リストを返す。
    """
    # "～" で分割して前半を開始日、後半を終了日とみなす
    splitted = date_period_str.split('～')
    if len(splitted) == 2:
        start_str = splitted[0].strip()
        end_str   = splitted[1].strip()

        start_date = parse_jp_date(start_str)  # 例）2020-12-02
        end_date   = parse_jp_date(end_str)    # 例）2020-12-04

        if start_date and end_date:
            result_dates = []
            delta_days = (end_date - start_date).days
            for i in range(delta_days + 1):
                d = start_date + datetime.timedelta(days=i)
                result_dates.append(d.strftime("%Y-%m-%d"))
            return result_dates

    # パースできない場合は空リスト
    return []

def main_transform(input_csv: str, output_csv: str):
    """
    取得したCSV(input_csv)を読み込み、
    変換後のCSV(output_csv)を作成する。
    ここで 'date_period' から
    複数の 'date' 行を展開して出力。
    """
    output_header = [
        "id",
        "name",
        "sub_title",
        "place",
        "actor",
        "date",
        "open_time",
        "start_time",
        "close_time",
        "time_original",
        "max_price",
        "min_price",
        "price_text",
        "link",
        "inquiry",
        "detail",
        "num_of_people",
        "input_table",
        "input_table_rec_id",
    ]
    
    with open(input_csv, mode="r", encoding="utf-8") as fin, \
         open(output_csv, mode="w", encoding="utf-8", newline="") as fout:
        
        reader = csv.DictReader(fin)
        writer = csv.writer(fout)
        
        # 変換後CSVのヘッダーを書き込み
        writer.writerow(output_header)
        
        row_id = 0  # id（複数行展開後も連番を振る）
        
        for row in reader:
            # (1) 元CSVの値を取得
            title        = row.get("title", "")
            sub_title    = row.get("category", "")
            place        = clean_facilities_str(row.get("facilities", ""))
            actor        = row.get("organizer", "")
            date_period  = row.get("date_period", "")
            time_main    = row.get("time_main", "")
            time_note    = row.get("time_note", "")
            detail_price = row.get("detail_price", "")
            link         = row.get("official_url", "")
            inquiry      = row.get("detail_url", "")
            detail       = row.get("description", "")
            
            # (2) 時間関連のパース
            open_t, close_t = parse_time_range(time_main)
            start_t = open_t  # 今回は start_time=open_time とする例
            time_original = time_main
            if time_note:
                time_original += f"（{time_note}）"
            
            # (3) 料金のパース
            max_price, min_price = parse_price(detail_price)
            
            # (4) 日付範囲を展開
            #  例）"2020年12月2日(水)～2020年12月4日(金)" -> ["2020-12-02", "2020-12-03", "2020-12-04"]
            date_list = expand_date_range(date_period)
            if not date_list:
                # 日付が取得できなかった場合、1行だけ出力する（空のdate）
                date_list = [""]
            
            # (5) 日付の数だけループし、それぞれ1行ずつ出力
            for one_date in date_list:
                row_id += 1
                
                output_row = [
                    row_id,          # id(連番)
                    title,           # name
                    sub_title,       # sub_title
                    place,           # place
                    actor,           # actor
                    one_date,        # date(YYYY-MM-DD)
                    open_t,          # open_time
                    start_t,         # start_time
                    close_t,         # close_time
                    time_original,   # time_original
                    max_price,       # max_price
                    min_price,       # min_price
                    detail_price,    # price_text
                    link,            # link
                    inquiry,         # inquiry
                    detail,          # detail
                    "",              # num_of_people(今回は空文字)
                    "csv",           # input_table(固定値)
                    row_id,          # input_table_rec_id(ここではidと同一を採用)
                ]
                
                writer.writerow(output_row)

    print(f"変換が完了しました。出力ファイル: {output_csv}")

if __name__ == "__main__":
    # 例として input.csv -> output.csv への変換を実行
    main_transform("events.csv", "output.csv")
# Out:
# 変換が完了しました。出力ファイル: output.csv

# %%
df = pd.read_csv("output.csv")

# %%
df[df['date']=="2025-01-20"]
# Out:
# Empty DataFrame
# Columns: [id, name, sub_title, place, actor, date, open_time, start_time, close_time, time_original, max_price, min_price, price_text, link, inquiry, detail, num_of_people, input_table, input_table_rec_id]
# Index: []

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'month'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df[df['month']==202411]
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pandas/core/frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~/.pyenv/versions/3.11.7/lib/python3.11/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'month'
